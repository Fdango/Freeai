# %% [markdown]
# ## jupyter 内嵌视频

# %%
from IPython.display import HTML

s = '''<iframe height=800 width=970 src="//player.bilibili.com/player.html?aid=46128995&cid=80820174&page=1" scrolling="no" border="0" frameborder="no" framespacing="0" allowfullscreen="true"> </iframe>'''
v=HTML(s)
v
# Out:
# <iframe height=800 width=970 src="//player.bilibili.com/player.html?aid=46128995&cid=80820174&page=1" scrolling="no" border="0" frameborder="no" framespacing="0" allowfullscreen="true"> </iframe>

# %%
from IPython.display import IFrame
IFrame('//player.bilibili.com/player.html?aid=46128995&cid=80820174&page=1', height='800', width='970', scrolling="no", border="0", frameborder="no", framespacing="0", allowfullscreen="true")
# Out:
#         <iframe
#             width="970"
#             height="800"
#             src="//player.bilibili.com/player.html?aid=46128995&cid=80820174&page=1?scrolling=no&border=0&frameborder=no&framespacing=0&allowfullscreen=true"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## jupyter 内嵌图片

# %%
from IPython.display import Image
Image(filename="OpenSourceLicenses.png")

# %% [markdown]
# ## jupyter 嵌入音乐

# %%
from IPython.display import Audio
Audio(filename="test.wma")

# %% [markdown]
# ## jupyter 嵌入网页

# %%
from IPython.display import IFrame
IFrame('http://www.w3school.com.cn/tags/tag_iframe.asp', height='900', width='970')
# Out:
#         <iframe
#             width="970"
#             height="900"
#             src="http://www.w3school.com.cn/tags/tag_iframe.asp"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## jupyter嵌入链接

# %%
from IPython.display import FileLink, FileLinks
FileLink('./1_OpenSourceLicenses.ipynb')
# Out:
# /home/sniper/Documents/blog/92_Licenses/1_OpenSourceLicenses.ipynb
